# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.read_csv('data.csv')

# %%
pd.set_option('display.max_columns',50)

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  03-09-2016       2.5    3067.0       2.0       1.0  1.0     126.0
# 1  03-12-2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 2  04-02-2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 3  04-02-2016       2.5    3067.0       3.0       2.0  1.0       0.0
# 4  04-03-2017       2.5    3067.0       3.0       2.0  0.0     134.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# ...

# %%
df.shape
#No. of Rows -23678
#No. of columns -21
# Out:
# (23678, 21)

# %%
#Datatypes of each column
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms            float64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
empty = df.apply(lambda x: x.isnull().all(), axis=1)
numOfRows = empty[empty == True].index
print('Number of Rows in dataframe which contain NaN in any column : ', numOfRows)
# Out:
# Number of Rows in dataframe which contain NaN in any column :  Int64Index([   31,  1145,  1348,  2119,  3277,  3288,  3745,  3752,  3798,
#              3855,
#             ...
#             21220, 21343, 21602, 22003, 22109, 22288, 22704, 22918, 23153,
#             23341],
#            dtype='int64', length=131)

# %%
empty = df.apply(lambda x: x.isnull().all(), axis=1)
numOfRows = len(empty[empty == True].index)
print('Number of Rows in dataframe which contain NaN in all column : ', numOfRows)
print('Percent of Rows in dataframe which contain NaN in all column : ', numOfRows/df.shape[0])
df.dropna(how='all',inplace=True)
print(df.shape)
# Out:
# Number of Rows in dataframe which contain NaN in all column :  131
# Percent of Rows in dataframe which contain NaN in all column :  0.005532561871779711
# (23547, 21)

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
empty = df.apply(lambda x: x.isnull().any(), axis=1)
numOfRows = empty[empty == True].index
print('Rows in dataframe which contain NaN in any column : ', numOfRows)
# Out:
# Rows in dataframe which contain NaN in any column :  Int64Index([    0,     1,     3,     5,     7,     8,     9,    10,    12,
#                13,
#             ...
#             23668, 23669, 23670, 23671, 23672, 23673, 23674, 23675, 23676,
#             23677],
#            dtype='int64', length=17351)

# %%
df.isnull().sum(axis=0) * 100 / len(df)
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price            21.875398
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.004247
# Postcode          0.004247
# Bedroom2         19.030025
# Bathroom         19.042766
# Car              19.645815
# Landsize         26.062768
# BuildingArea     57.455302
# YearBuilt        50.991634
# CouncilArea      33.511700
# Lattitude        18.278337
# Longtitude       18.278337
# Regionname        0.004247
# Propertycount     0.004247
# dtype: float64

# %%
df.isnull().sum(axis=1) * 100 / len(df)
# Out:
# 0        0.012740
# 1        0.008494
# 2        0.000000
# 3        0.012740
# 4        0.000000
#            ...
# 23673    0.008494
# 23674    0.033975
# 23675    0.016987
# 23676    0.004247
# 23677    0.008494
# Length: 23547, dtype: float64

# %%
empty=df.isnull().sum(axis=0) * 100 / len(df)>30.0
m=empty[empty==True]
print(m)
df.drop(['BuildingArea','YearBuilt','CouncilArea'],axis=1,inplace=True)
# Out:
# BuildingArea    True
# YearBuilt       True
# CouncilArea     True
# dtype: bool

# %%
if(len(df[df.isnull().sum(axis=1)>5])/len(df)<0.20):
    df.drop(df[df.isnull().sum(axis=1)>5].index,inplace=True)
else:
    print('The percentage of rows is less than 20%')

# %%
df.shape
# Out:
# (19269, 18)

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  19269.000000  1.508600e+04  19269.000000  19269.000000  19066.000000
# mean       2.973117  1.066695e+06     10.204365   3110.015777      2.951956
# std        0.978969  6.389331e+05      6.065786     93.730487      0.996032
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.400000e+05      6.100000   3049.000000      2.000000
# 50%        3.000000  9.000000e+05      9.200000   3102.000000      3.000000
# 75%        4.000000  1.320000e+06     13.000000   3150.000000      4.000000
# max       12.000000  9.000000e+06     48.100000   3977.000000     30.000000
#
#            Bathroom           Car       Landsize     Lattitude    Longtitude  \
# count  19063.000000  18921.000000   17410.000000  19243.000000  19243.000000
# mean       1.570897      1.626235     551.783458    -37.812434    145.000287
# ...

# %%
df.head(30)
# Out:
#         Suburb              Address  Rooms Type      Price Method  SellerG  \
# 0   Abbotsford        68 Studley St    2.0    h        NaN     SS   Jellis
# 1   Abbotsford         85 Turner St    2.0    h  1480000.0      S   Biggin
# 2   Abbotsford      25 Bloomburg St    2.0    h  1035000.0      S   Biggin
# 3   Abbotsford   18/659 Victoria St    3.0    u        NaN     VB   Rounds
# 4   Abbotsford         5 Charles St    3.0    h  1465000.0     SP   Biggin
# 5   Abbotsford     40 Federation La    3.0    h   850000.0     PI   Biggin
# 6   Abbotsford          55a Park St    4.0    h  1600000.0     VB   Nelson
# 7   Abbotsford         16 Maugie St    4.0    h        NaN     SN   Nelson
# 8   Abbotsford         53 Turner St    2.0    h        NaN      S   Biggin
# 9   Abbotsford         99 Turner St    2.0    h        NaN      S  Collins
# 10  Abbotsford       129 Charles St    2.0    h   941000.0      S   Jellis
# ...

# %%
df.dropna(subset=['Price'],inplace=True)

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 1  Abbotsford      85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford   25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 4  Abbotsford      5 Charles St    3.0    h  1465000.0     SP  Biggin
# 5  Abbotsford  40 Federation La    3.0    h   850000.0     PI  Biggin
# 6  Abbotsford       55a Park St    4.0    h  1600000.0     VB  Nelson
#
#          Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 1  03-12-2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 2  04-02-2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 4  04-03-2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 5  04-03-2017       2.5    3067.0       3.0       2.0  1.0      94.0
# 6  04-06-2016       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    Lattitude  Longtitude             Regionname  Propertycount
# 1   -37.7996    144.9984  Northern Metropolitan         4019.0
# ...

# %%
df.isnull().sum(axis=0)*100/len(df)
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Price            0.000000
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000000
# Postcode         0.000000
# Bedroom2         1.053957
# Bathroom         1.067215
# Car              1.763224
# Landsize         9.830306
# Lattitude        0.145831
# Longtitude       0.145831
# Regionname       0.000000
# Propertycount    0.000000
# dtype: float64

# %%
df.dropna(subset=['Bedroom2','Bathroom','Car','Landsize','Lattitude','Longtitude'],inplace=True)

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 1  Abbotsford      85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford   25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 4  Abbotsford      5 Charles St    3.0    h  1465000.0     SP  Biggin
# 5  Abbotsford  40 Federation La    3.0    h   850000.0     PI  Biggin
# 6  Abbotsford       55a Park St    4.0    h  1600000.0     VB  Nelson
#
#          Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 1  03-12-2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 2  04-02-2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 4  04-03-2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 5  04-03-2017       2.5    3067.0       3.0       2.0  1.0      94.0
# 6  04-06-2016       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    Lattitude  Longtitude             Regionname  Propertycount
# 1   -37.7996    144.9984  Northern Metropolitan         4019.0
# ...

# %%
1-df.shape[1]/21
#14 % of columns are removed
# Out:
# 0.1428571428571429

# %%
1-df.shape[0]/23678
# 42% of the rows are removed
# Out:
# 0.4290902947884112
